# %% [markdown]
# # Pencil Sketch with Python

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Collecting numpy>=2 (from opencv-python)
#   Downloading numpy-2.4.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 5.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading numpy-2.4.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 5.5 MB/s eta 0:00:000:00:01m eta 0:00:01
# Installing collected packages: numpy, opencv-python
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [opencv-python]m 1/2 [opencv-python]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xgboost 2.1.1 requires nvidia-nccl-cu12; platform_system == "Linux" and platform_machine != "aarch64", which is not installed.
# ydata-profiling 4.16.1 requires numpy<2.2,>=1.16.0, but you have numpy 2.4.2 which is incompatible.
# mizani 0.14.2 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# apache-superset 6.0.0 requires numpy<2.3,>1.23.5, but you have numpy 2.4.2 which is incompatible.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.4.2 which is incompatible.
# plotnine 0.15.0 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# pandas 2.1.4 requires numpy<2,>=1.23.2; python_version == "3.11", but you have numpy 2.4.2 which is incompatible.
# Successfully installed numpy-2.4.2 opencv-python-4.13.0.92
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
image = cv2.imread("beach.jpg")
cv2.imshow("Beach", image)
cv2.waitKey(0)
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# QFontDatabase: Cannot find font directory /home/ochwo-edrian-jude/miniconda3/envs/ds4b/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ochwo-edrian-jude/miniconda3/envs/ds4b/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ochwo-edrian-jude/miniconda3/envs/ds4b/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ochwo-edrian-jude/miniconda3/envs/ds4b/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ochwo-edrian-jude/miniconda3/envs/ds4b/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# -1

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("New Beach", gray_image)
cv2.waitKey(0)
# Out:
# -1

# %%
inverted_image = 255 - gray_image
cv2.imshow("Inverted", inverted_image)
cv2.waitKey()
# Out:
# -1

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2.imshow("sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow("original image", image)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# 32
