# %% [markdown]
# # Future Sales Prediction with Machine Learning

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import plotly.express as px
import plotly.graph_objects as go

# %%
data = pd.read_csv("advertising.csv")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data2 = pd.read_csv("advertising.csv")
data2.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
TV_sum = sum(data2.TV)
Radio_sum = sum(data2.Radio)
Newspaper_sum = sum(data2.Newspaper)
Sales_sum = sum(data2.Sales)

Total = (TV_sum + Radio_sum + Newspaper_sum + Sales_sum)
pTV = ((TV_sum/Total)*100)
pRadio = ((Radio_sum/Total)*100)
pNewspaper = ((Newspaper_sum/Total)*100)
pSales = ((Sales_sum/Total)*100)

figure = px.pie(values = )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 12
#       9 pNewspaper = ((Newspaper_sum/Total)*100)
#      10 pSales = ((Sales_sum/Total)*100)
# ---> 12 Values = Values[[0, 1, 2, 3]]
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
print(data2.isnull().sum())
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# ## The relationship between the sales and the advertising on TV

# %%
figure = px.scatter(data_frame = data2, x = "Sales",
                   y = "TV", size = "TV", trendline = "ols"
                   )
figure.show()

# %%
figure = px.scatter(data_frame = data2, x = "Sales",
                   y = "Radio",size = "Radio", trendline = "ols")
figure.show()

# %%
figure = px.scatter(data_frame = data2, x = "Sales",
                   y = "Newspaper",size = "Newspaper",
                   trendline = "ols"
                   )
figure.show()

# %%
# Lets check check if this dataset contains any Null values or not
print(data.isnull().sum())
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
#relationship between the Sales and the advertising on TV
figure = px.scatter(data_frame = data, x = "Sales",
                   y = "TV", size = "TV", trendline = "ols"
                   )
figure.show()

# %%
#relationship between the Sales and the advertising on Newspaper
figure = px.scatter(data_frame = data, x = "Sales",
                   y = "Newspaper", size = "Newspaper", trendline = "ols")
figure.show()

# %%
##relationship between the Sales and the advertising on Radio
figure = px.scatter(data_frame = data, x = "Sales",
                   y = "Radio", size = "Radio", trendline = "ols")

figure.show()

# %%
figure = px.pie()

# %%
#lets look at the correlation of all the columns with the sales column
correlation  = data.corr()
print(correlation["Sales"].sort_values(ascending = False))
# Out:
# Sales        1.000000
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Name: Sales, dtype: float64

# %% [markdown]
# ## Future Sales Prediction Model

# %%
x = np.array(data.drop(["Sales"], axis = 1))
y = np.array(data["Sales"])

xtrain, xtest, ytrain, ytest =  train_test_split(x,y,
                                                test_size = 0.2,
                                                random_state = 42)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
print(model.score(xtest, ytest))
# Out:
# 0.9059011844150826

# %%
# Lets do some prediction, accroding the training features
#features = [[TV, Radio, Newspaper]]
features = np.array([[230.1, 37.8, 69.2]])
print(model.predict(features))
# Out:
# [21.37254028]
